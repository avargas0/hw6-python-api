# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities. 
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations. 
# AMY: You will need to change size to 1500 when finished.
lats = np.random.uniform(low=-90.000, high=90.000, size=50)
lngs = np.random.uniform(low=-180.000, high=180.000, size=50)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 40

# %%
len(lats)
# Out:
# 50

# %%
len(lngs)
# Out:
# 50

# %%
#Each time you run this cell, the list of cities will change.
cities
# Out:
# ['saint-philippe',
#  'bardiyah',
#  'busselton',
#  'coihaique',
#  'mataura',
#  'mys shmidta',
#  'mar del plata',
#  'la ronge',
#  'tual',
#  'arraial do cabo',
#  'baykit',
#  'illoqqortoormiut',
#  'samusu',
#  'albany',
#  'cape town',
#  'esperance',
#  'punta arenas',
#  'ambilobe',
#  'tutoia',
#  'yanchukan',
#  'xai-xai',
#  'aklavik',
#  'tilichiki',
#  'luderitz',
#  'port alfred',
#  'port elizabeth',
#  'san patricio',
#  'bluff',
#  'ushuaia',
#  'sovetskiy',
#  'kodiak',
#  'qibili',
#  'solnechnyy',
#  'tuktoyaktuk',
#  'richards bay',
#  'hobart',
#  'khatanga',
#  'iqaluit',
#  'keetmanshoop',
#  'hermanus']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Per the OpenWeatherMap documentation, the API call site is
#api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}
#Hard-coded Hobert's key

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = 'imperial'

query_url = f"{base_url}appid={api_key}&units={units}&q="

# %%
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=b166427b562ac5e837a3fb19dd1e2215&units=imperial&q=

# %%
#Get weather data (temperature, humidity, cloudiness, wind speed)
temp = []
humidity = []
cloudiness = []
wind_speed = []

count = 0
count_all = 0
count_error = 0

city_name = []

for city in cities: 
    count_all = count_all + 1
    print("Beginning data retrieval." + str(count_all) + "for" + city + ".") 
    
    try:
        response = requests.get(query_url + city).json()

        pprint(response)
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        
        city_name.append(city)
        
        count = count + 1
    
    except: 
        count_error = count_error + 1
        print("Data missing.")
# Out:
# Beginning data retrieval.1forsaint-philippe.
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 45.36, 'lon': -73.48},
#  'dt': 1547055480,
#  'id': 6138908,
#  'main': {'humidity': 99,
#           'pressure': 995,
#           'temp': 32.74,
#           'temp_max': 33.8,
#           'temp_min': 31.1},
#  'name': 'Saint-Philippe',
#  'sys': {'country': 'CA',
#          'id': 820,
#          'message': 0.0037,
#          'sunrise': 1547037132,
#          'sunset': 1547069442,
#          'type': 1},
#  'visibility': 6437,
#  'weather': [{'description': 'light snow',
#               'icon': '13d',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 320, 'gust': 7.7, 'speed': 11.41}}
# Beginning data retrieval.2forbardiyah.
# {'cod': '404', 'message': 'city not found'}
# Data missing.
# Beginning data retrieval.3forbusselton.
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.64, 'lon': 115.35},
#  'dt': 1547056548,
#  'id': 2075265,
#  'main': {'grnd_level': 1023.27,
#           'humidity': 100,
#           'pressure': 1023.27,
#           'sea_level': 1024.36,
#           'temp': 64.93,
#           'temp_max': 64.93,
#           'temp_min': 64.93},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'message': 0.0142,
#          'sunrise': 1546982311,
#          'sunset': 1547033565},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 184.502, 'speed': 12.1}}
# Beginning data retrieval.4forcoihaique.
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -45.58, 'lon': -72.07},
#  'dt': 1547053200,
#  'id': 3894426,
#  'main': {'humidity': 54,
#           'pressure': 1017,
#           'temp': 54.77,
#           'temp_max': 55.4,
#           'temp_min': 53.6},
#  'name': 'Coihaique',
#  'sys': {'country': 'CL',
#          'id': 8491,
#          'message': 0.0171,
#          'sunrise': 1547025146,
#          'sunset': 1547080704,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'speed': 5.82}}
# Beginning data retrieval.5formataura.
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1547057122,
#  'id': 6201424,
#  'main': {'grnd_level': 1006.97,
#           'humidity': 97,
#           'pressure': 1006.97,
#           'sea_level': 1021.88,
#           'temp': 53.41,
#           'temp_max': 53.41,
#           'temp_min': 53.41},
#  'name': 'Mataura',
#  'rain': {'3h': 0.9},
#  'sys': {'country': 'NZ',
#          'message': 0.0041,
#          'sunrise': 1546967134,
#          'sunset': 1547023036},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 251.002, 'speed': 4.94}}
# Beginning data retrieval.6formys shmidta.
# {'cod': '404', 'message': 'city not found'}
# Data missing.
# Beginning data retrieval.7formar del plata.
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -46.43, 'lon': -67.52},
#  'dt': 1547056954,
#  'id': 3863379,
#  'main': {'grnd_level': 1005.92,
#           'humidity': 49,
#           'pressure': 1005.92,
#           'sea_level': 1027.35,
#           'temp': 58.45,
#           'temp_max': 58.45,
#           'temp_min': 58.45},
#  'name': 'Mar del Plata',
#  'sys': {'country': 'AR',
#          'message': 0.1394,
#          'sunrise': 1547023857,
#          'sunset': 1547079807},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170.502, 'speed': 11.1}}
# Beginning data retrieval.8forla ronge.
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 55.1, 'lon': -105.3},
#  'dt': 1547053200,
#  'id': 6050066,
#  'main': {'humidity': 75,
#           'pressure': 1031,
#           'temp': -13.01,
#           'temp_max': -13.01,
#           'temp_min': -13.01},
#  'name': 'La Ronge',
#  'sys': {'country': 'CA',
#          'id': 949,
#          'message': 0.0177,
#          'sunrise': 1547047337,
#          'sunset': 1547074520,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 3.36}}
# Beginning data retrieval.9fortual.
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': -5.67, 'lon': 132.75},
#  'dt': 1547056954,
#  'id': 1623197,
#  'main': {'grnd_level': 1021.41,
#           'humidity': 100,
#           'pressure': 1021.41,
#           'sea_level': 1021.92,
#           'temp': 81.76,
#           'temp_max': 81.76,
#           'temp_min': 81.76},
#  'name': 'Tual',
#  'rain': {'3h': 2.4},
#  'sys': {'country': 'ID',
#          'message': 0.0027,
#          'sunrise': 1546981392,
#          'sunset': 1547026144},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 261.502, 'speed': 14}}
# Beginning data retrieval.10forarraial do cabo.
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -22.97, 'lon': -42.02},
#  'dt': 1547053200,
#  'id': 3471451,
#  'main': {'humidity': 62,
#           'pressure': 1015,
#           'temp': 87.93,
#           'temp_max': 91.4,
#           'temp_min': 84.2},
#  'name': 'Arraial do Cabo',
#  'sys': {'country': 'BR',
#          'id': 8326,
#          'message': 0.0041,
#          'sunrise': 1547021513,
#          'sunset': 1547069929,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 100, 'speed': 24.16}}
# Beginning data retrieval.11forbaykit.
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 61.68, 'lon': 96.39},
#  'dt': 1547056955,
#  'id': 1510689,
#  'main': {'grnd_level': 948.29,
#           'humidity': 79,
#           'pressure': 948.29,
#           'sea_level': 1014.02,
#           'temp': 2.96,
#           'temp_max': 2.96,
#           'temp_min': 2.96},
#  'name': 'Baykit',
#  'sys': {'country': 'RU',
#          'message': 0.0099,
#          'sunrise': 1547001918,
#          'sunset': 1547023105},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 161.002, 'speed': 3.49}}
# Beginning data retrieval.12forilloqqortoormiut.
# {'cod': '404', 'message': 'city not found'}
# Data missing.
# Beginning data retrieval.13forsamusu.
# {'cod': '404', 'message': 'city not found'}
# Data missing.
# Beginning data retrieval.14foralbany.
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 42.65, 'lon': -73.75},
#  'dt': 1547056320,
#  'id': 5106834,
#  'main': {'humidity': 64,
#           'pressure': 998,
#           'temp': 35.38,
#           'temp_max': 39.02,
#           'temp_min': 32},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 3273,
#          'message': 0.0037,
#          'sunrise': 1547036665,
#          'sunset': 1547070037,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'light snow',
#               'icon': '13d',
#               'id': 600,
#               'main': 'Snow'},
#              {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 270, 'gust': 17, 'speed': 21.92}}
# Beginning data retrieval.15forcape town.
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1547053200,
#  'id': 3369157,
#  'main': {'humidity': 64,
#           'pressure': 1010,
#           'temp': 69.8,
#           'temp_max': 69.8,
#           'temp_min': 69.8},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 1899,
#          'message': 0.2257,
#          'sunrise': 1547005545,
#          'sunset': 1547056870,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 190, 'speed': 21.92}}
# Beginning data retrieval.16foresperance.
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 10.24, 'lon': -61.45},
#  'dt': 1547053200,
#  'id': 3573739,
#  'main': {'humidity': 48,
#           'pressure': 1013,
#           'temp': 87.8,
#           'temp_max': 87.8,
#           'temp_min': 87.8},
#  'name': 'Esperance',
#  'sys': {'country': 'TT',
#          'id': 8810,
#          'message': 0.0048,
#          'sunrise': 1547029569,
#          'sunset': 1547071215,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'shower rain',
#               'icon': '09d',
#               'id': 521,
#               'main': 'Rain'}],
#  'wind': {'deg': 110, 'speed': 13.87}}
# Beginning data retrieval.17forpunta arenas.
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -53.16, 'lon': -70.91},
#  'dt': 1547053200,
#  'id': 3874787,
#  'main': {'humidity': 35,
#           'pressure': 1010,
#           'temp': 57.2,
#           'temp_max': 57.2,
#           'temp_min': 57.2},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'message': 0.03,
#          'sunrise': 1547022784,
#          'sunset': 1547082493,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 230, 'speed': 29.97}}
# Beginning data retrieval.18forambilobe.
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -13.19, 'lon': 49.05},
#  'dt': 1547056956,
#  'id': 1082243,
#  'main': {'grnd_level': 1002.03,
#           'humidity': 100,
#           'pressure': 1002.03,
#           'sea_level': 1025.94,
#           'temp': 71.5,
#           'temp_max': 71.5,
#           'temp_min': 71.5},
#  'name': 'Ambilobe',
#  'rain': {'3h': 7.17},
#  'sys': {'country': 'MG',
#          'message': 0.0032,
#          'sunrise': 1547000726,
#          'sunset': 1547046994},
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 158.002, 'speed': 4.5}}
# Beginning data retrieval.19fortutoia.
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -2.76, 'lon': -42.27},
#  'dt': 1547053200,
#  'id': 3385899,
#  'main': {'humidity': 58,
#           'pressure': 1009,
#           'temp': 84.2,
#           'temp_max': 84.2,
#           'temp_min': 84.2},
#  'name': 'Tutoia',
#  'sys': {'country': 'BR',
#          'id': 8404,
#          'message': 0.0041,
#          'sunrise': 1547023696,
#          'sunset': 1547067875,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 16.11}}
# Beginning data retrieval.20foryanchukan.
# {'cod': '404', 'message': 'city not found'}
# Data missing.
# Beginning data retrieval.21forxai-xai.
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': -25.04, 'lon': 33.64},
#  'dt': 1547056957,
#  'id': 1024552,
#  'main': {'grnd_level': 1019.46,
#           'humidity': 100,
#           'pressure': 1019.46,
#           'sea_level': 1021.88,
#           'temp': 75.86,
#           'temp_max': 75.86,
#           'temp_min': 75.86},
#  'name': 'Xai-Xai',
#  'sys': {'country': 'MZ',
#          'message': 0.0387,
#          'sunrise': 1547003095,
#          'sunset': 1547052018},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 102.502, 'speed': 9.31}}
# Beginning data retrieval.22foraklavik.
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 68.22, 'lon': -135.01},
#  'dt': 1547054820,
#  'id': 5882953,
#  'main': {'humidity': 65,
#           'pressure': 1032,
#           'temp': -35.34,
#           'temp_max': -32.81,
#           'temp_min': -38.21},
#  'name': 'Aklavik',
#  'sys': {'country': 'CA',
#          'id': 821,
#          'message': 0.0037,
#          'sunrise': 1547064449,
#          'sunset': 1547071684,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 140, 'speed': 3.36}}
# Beginning data retrieval.23fortilichiki.
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 60.47, 'lon': 166.1},
#  'dt': 1547056958,
#  'id': 2120591,
#  'main': {'grnd_level': 986.47,
#           'humidity': 86,
#           'pressure': 986.47,
#           'sea_level': 1006.4,
#           'temp': 14.71,
#           'temp_max': 14.71,
#           'temp_min': 14.71},
#  'name': 'Tilichiki',
#  'sys': {'country': 'RU',
#          'message': 0.0079,
#          'sunrise': 1546984520,
#          'sunset': 1547007031},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 18.5023, 'speed': 7.18}}
# Beginning data retrieval.24forluderitz.
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -26.65, 'lon': 15.16},
#  'dt': 1547056958,
#  'id': 3355672,
#  'main': {'grnd_level': 1011.11,
#           'humidity': 78,
#           'pressure': 1011.11,
#           'sea_level': 1025.33,
#           'temp': 63.53,
#           'temp_max': 63.53,
#           'temp_min': 63.53},
#  'name': 'Luderitz',
#  'sys': {'country': 'NA',
#          'message': 0.0035,
#          'sunrise': 1547007332,
#          'sunset': 1547056654},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 181.002, 'speed': 12.77}}
# Beginning data retrieval.25forport alfred.
# {'base': 'stations',
#  'clouds': {'all': 56},
#  'cod': 200,
#  'coord': {'lat': -33.59, 'lon': 26.89},
#  'dt': 1547056958,
#  'id': 964432,
#  'main': {'grnd_level': 1010.62,
#           'humidity': 84,
#           'pressure': 1010.62,
#           'sea_level': 1019.33,
#           'temp': 72.85,
#           'temp_max': 72.85,
#           'temp_min': 72.85},
#  'name': 'Port Alfred',
#  'sys': {'country': 'ZA',
#          'message': 0.0057,
#          'sunrise': 1547003562,
#          'sunset': 1547054787},
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 71.5023, 'speed': 16.24}}
# Beginning data retrieval.26forport elizabeth.
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 39.31, 'lon': -74.98},
#  'dt': 1547052900,
#  'id': 4501427,
#  'main': {'humidity': 47,
#           'pressure': 1005,
#           'temp': 45.21,
#           'temp_max': 46.04,
#           'temp_min': 44.06},
#  'name': 'Port Elizabeth',
#  'sys': {'country': 'US',
#          'id': 4902,
#          'message': 0.0042,
#          'sunrise': 1547036373,
#          'sunset': 1547070918,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'gust': 15.9, 'speed': 19.46}}
# Beginning data retrieval.27forsan patricio.
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': -26.98, 'lon': -56.83},
#  'dt': 1547057127,
#  'id': 3437029,
#  'main': {'grnd_level': 1010.14,
#           'humidity': 62,
#           'pressure': 1010.14,
#           'sea_level': 1019.86,
#           'temp': 89.68,
#           'temp_max': 89.68,
#           'temp_min': 89.68},
#  'name': 'San Patricio',
#  'sys': {'country': 'PY',
#          'message': 0.0031,
#          'sunrise': 1547024577,
#          'sunset': 1547073974},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 342.502, 'speed': 9.98}}
# Beginning data retrieval.28forbluff.
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -23.58, 'lon': 149.07},
#  'dt': 1547056551,
#  'id': 2175403,
#  'main': {'grnd_level': 1001.14,
#           'humidity': 96,
#           'pressure': 1001.14,
#           'sea_level': 1023.83,
#           'temp': 70.15,
#           'temp_max': 70.15,
#           'temp_min': 70.15},
#  'name': 'Bluff',
#  'rain': {'3h': 0.12},
#  'sys': {'country': 'AU',
#          'message': 0.0085,
#          'sunrise': 1546975556,
#          'sunset': 1547024137},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 94.0023, 'speed': 10.65}}
# Beginning data retrieval.29forushuaia.
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -54.81, 'lon': -68.31},
#  'dt': 1547053200,
#  'id': 3833367,
#  'main': {'humidity': 61,
#           'pressure': 1007,
#           'temp': 51.24,
#           'temp_max': 53.6,
#           'temp_min': 48.2},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'message': 0.0037,
#          'sunrise': 1547021570,
#          'sunset': 1547082453,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 23.04}}
# Beginning data retrieval.30forsovetskiy.
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': 56.76, 'lon': 48.47},
#  'dt': 1547056981,
#  'id': 490040,
#  'main': {'grnd_level': 1012.16,
#           'humidity': 91,
#           'pressure': 1012.16,
#           'sea_level': 1034,
#           'temp': 12.55,
#           'temp_max': 12.55,
#           'temp_min': 12.55},
#  'name': 'Sovetskiy',
#  'sys': {'country': 'RU',
#          'message': 0.0034,
#          'sunrise': 1547011057,
#          'sunset': 1547036970},
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 234.002, 'speed': 9.08}}
# Beginning data retrieval.31forkodiak.
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 39.95, 'lon': -94.76},
#  'dt': 1547055300,
#  'id': 4407665,
#  'main': {'humidity': 65,
#           'pressure': 1033,
#           'temp': 31.6,
#           'temp_max': 32,
#           'temp_min': 30.74},
#  'name': 'Kodiak',
#  'sys': {'country': 'US',
#          'id': 4022,
#          'message': 0.0033,
#          'sunrise': 1547041227,
#          'sunset': 1547075561,
#          'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 340, 'speed': 13.87}}
# Beginning data retrieval.32forqibili.
# {'cod': '404', 'message': 'city not found'}
# Data missing.
# Beginning data retrieval.33forsolnechnyy.
# {'base': 'stations',
#  'clouds': {'all': 8},
#  'cod': 200,
#  'coord': {'lat': 50.72, 'lon': 136.64},
#  'dt': 1547056981,
#  'id': 2016307,
#  'main': {'grnd_level': 996.36,
#           'humidity': 43,
#           'pressure': 996.36,
#           'sea_level': 1019.45,
#           'temp': -14.59,
#           'temp_max': -14.59,
#           'temp_min': -14.59},
#  'name': 'Solnechnyy',
#  'sys': {'country': 'RU',
#          'message': 0.0047,
#          'sunrise': 1546987974,
#          'sunset': 1547017716},
#  'weather': [{'description': 'clear sky',
#               'icon': '02n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 191.002, 'speed': 1.81}}
# Beginning data retrieval.34fortuktoyaktuk.
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 69.44, 'lon': -133.03},
#  'dt': 1547053200,
#  'id': 6170031,
#  'main': {'humidity': 65,
#           'pressure': 1032,
#           'temp': -34.61,
#           'temp_max': -34.61,
#           'temp_min': -34.61},
#  'name': 'Tuktoyaktuk',
#  'sys': {'country': 'CA',
#          'id': 942,
#          'message': 0.004,
#          'sunrise': 0,
#          'sunset': 0,
#          'type': 1},
#  'visibility': 24140,
#  'weather': [{'description': 'clear sky',
#               'icon': '02d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 230, 'speed': 2.24}}
# Beginning data retrieval.35forrichards bay.
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -28.77, 'lon': 32.06},
#  'dt': 1547056982,
#  'id': 962367,
#  'main': {'grnd_level': 1003.65,
#           'humidity': 86,
#           'pressure': 1003.65,
#           'sea_level': 1021.44,
#           'temp': 73.03,
#           'temp_max': 73.03,
#           'temp_min': 73.03},
#  'name': 'Richards Bay',
#  'sys': {'country': 'ZA',
#          'message': 0.0037,
#          'sunrise': 1547002998,
#          'sunset': 1547052871},
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 66.0023, 'speed': 6.96}}
# Beginning data retrieval.36forhobart.
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1547055000,
#  'id': 2163355,
#  'main': {'humidity': 54,
#           'pressure': 1012,
#           'temp': 55.4,
#           'temp_max': 55.4,
#           'temp_min': 55.4},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 9545,
#          'message': 0.004,
#          'sunrise': 1546973026,
#          'sunset': 1547027486,
#          'type': 1},
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'speed': 12.75}}
# Beginning data retrieval.37forkhatanga.
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 71.98, 'lon': 102.47},
#  'dt': 1547057129,
#  'id': 2022572,
#  'main': {'grnd_level': 1015.17,
#           'humidity': 61,
#           'pressure': 1015.17,
#           'sea_level': 1020.46,
#           'temp': -21.07,
#           'temp_max': -21.07,
#           'temp_min': -21.07},
#  'name': 'Khatanga',
#  'sys': {'country': 'RU', 'message': 0.003, 'sunrise': 0, 'sunset': 0},
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 172.502, 'speed': 3.94}}
# Beginning data retrieval.38foriqaluit.
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 63.75, 'lon': -68.52},
#  'dt': 1547053200,
#  'id': 5983720,
#  'main': {'humidity': 68,
#           'pressure': 1023,
#           'temp': -14.81,
#           'temp_max': -14.81,
#           'temp_min': -14.81},
#  'name': 'Iqaluit',
#  'sys': {'country': 'CA',
#          'id': 797,
#          'message': 0.0255,
#          'sunrise': 1547042853,
#          'sunset': 1547061351,
#          'type': 1},
#  'visibility': 32186,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 320, 'speed': 13.87}}
# Beginning data retrieval.39forkeetmanshoop.
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -26.57, 'lon': 18.15},
#  'dt': 1547053200,
#  'id': 3356264,
#  'main': {'humidity': 12,
#           'pressure': 1010,
#           'temp': 86,
#           'temp_max': 86,
#           'temp_min': 86},
#  'name': 'Keetmanshoop',
#  'sys': {'country': 'NA',
#          'id': 2264,
#          'message': 0.0034,
#          'sunrise': 1547006624,
#          'sunset': 1547055926,
#          'type': 1},
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 190, 'speed': 11.41}}
# Beginning data retrieval.40forhermanus.
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.24},
#  'dt': 1547056983,
#  'id': 3366880,
#  'main': {'grnd_level': 984.28,
#           'humidity': 91,
#           'pressure': 984.28,
#           'sea_level': 1023.34,
#           'temp': 63.76,
#           'temp_max': 63.76,
#           'temp_min': 63.76},
#  'name': 'Hermanus',
#  'rain': {'3h': 0.67},
#  'sys': {'country': 'ZA',
#          'message': 0.0033,
#          'sunrise': 1547005273,
#          'sunset': 1547056748},
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 207.502, 'speed': 3.49}}

# %%
print(city_name)
# Out:
# ['saint-philippe', 'busselton', 'coihaique', 'mataura', 'mar del plata', 'la ronge', 'tual', 'arraial do cabo', 'baykit', 'albany', 'cape town', 'esperance', 'punta arenas', 'ambilobe', 'tutoia', 'xai-xai', 'aklavik', 'tilichiki', 'luderitz', 'port alfred', 'port elizabeth', 'san patricio', 'bluff', 'ushuaia', 'sovetskiy', 'kodiak', 'solnechnyy', 'tuktoyaktuk', 'richards bay', 'hobart', 'khatanga', 'iqaluit', 'keetmanshoop', 'hermanus']

# %%
len(city_name)
# Out:
# 34

# %%
print(count)
# Out:
# 34

# %%
print(count_error)
# Out:
# 6

# %%
print(count_all)
# Out:
# 40

# %%
print(temp)
# Out:
# [32.74, 64.93, 54.77, 53.41, 58.45, -13.01, 81.76, 87.91, 2.96, 35.38, 69.8, 87.8, 57.2, 71.5, 84.2, 75.86, -35.36, 14.71, 63.53, 72.85, 45.21, 89.68, 70.15, 51.24, 12.55, 31.59, -14.59, -34.61, 73.03, 55.4, -21.07, -14.81, 86, 63.76]

# %%
len(temp)
# Out:
# 34

# %%
print(humidity)
# Out:
# [99, 100, 54, 97, 49, 75, 100, 62, 79, 64, 64, 48, 35, 100, 58, 100, 65, 86, 78, 84, 47, 62, 96, 61, 91, 65, 43, 65, 86, 54, 61, 68, 12, 91]

# %%
len(humidity)
# Out:
# 34

# %%
print(cloudiness)
# Out:
# [90, 0, 40, 88, 88, 75, 56, 0, 64, 90, 40, 40, 0, 92, 75, 48, 40, 80, 0, 56, 75, 32, 92, 75, 92, 1, 8, 5, 0, 20, 48, 75, 0, 92]

# %%
len(cloudiness)
# Out:
# 34

# %%
print(wind_speed)
# Out:
# [11.41, 12.1, 5.82, 4.94, 11.1, 3.36, 14, 24.16, 3.49, 21.92, 21.92, 13.87, 29.97, 4.5, 16.11, 9.31, 3.36, 7.18, 12.77, 16.24, 18.34, 9.98, 10.65, 23.04, 9.08, 13.87, 1.81, 2.24, 6.96, 12.75, 3.94, 13.87, 11.41, 3.49]

# %%
len(wind_speed)
# Out:
# 34

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_weather = {"city": city_name,
               "temperature": temp,
               "humidity": humidity,
               "cloudiness": cloudiness,
               "wind speed": wind_speed}
city_weather_df = pd.DataFrame(city_weather)
city_weather_df.head()
# Out:
#              city  temperature  humidity  cloudiness  wind speed
# 0  saint-philippe        32.74        99          90       11.41
# 1       busselton        64.93       100           0       12.10
# 2       coihaique        54.77        54          40        5.82
# 3         mataura        53.41        97          88        4.94
# 4   mar del plata        58.45        49          88       11.10

# %%
city_weather_df.to_csv("city_weather_df",index=False,header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
